# %%
import pandas as pd
import matplotlib as plot

# %%
df = pd.read_csv('arq.csv')
df
# Out:
#         Data    CO     O3  temp  umid
# 0     Jan. 1   6.6  113.6  15.2    56
# 1     Jan. 2   6.2  115.2  15.5    55
# 2     Jan. 3   7.9  130.4  16.8    62
# 3     Jan. 4   8.6  110.4  16.4    96
# 4     Jan. 5   8.8  107.2  15.2    62
# ..       ...   ...    ...   ...   ...
# 115  Abr. 26   9.0    2.7  15.9    82
# 116  Abr. 27   8.9   11.2  14.1    75
# 117  Abr. 28  10.3   33.1  14.5    58
# 118  Abr. 29   6.1   34.4  14.0    64
# 119  Abr. 30   7.0   53.6  15.1    73
#
# [120 rows x 5 columns]

# %%
df['saldo'] = (df['CO'] + df['O3'] + df['temp'] + df['umid'])*10 + df['umid']/100
for i in range(120):
    df['saldo'][i] = float(f"{float(df['saldo'][i]):.2f}")
df
# Out:
# C:\Users\lcone\AppData\Local\Temp\ipykernel_1336\2822148354.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['saldo'][i] = float(f"{float(df['saldo'][i]):.2f}")
# ...

# %%
dfcontas = df[['Data','saldo']]

indices_formatados = [f"{i + 1:04d}" for i in dfcontas.index]


lista = [
"Ana", "Bruno", "Carlos", "Daniela", "Eduardo", "Fernanda", "Gabriel", "Helena", "Igor", "Joana",
    "Kleber", "Larissa", "Marcos", "Natalia", "Otavio", "Paula", "Quesia", "Ricardo", "Sofia", "Tiago",
    "Ursula", "Vitor", "Wagner", "Ximena", "Yasmin", "Zeca",
    "Alice", "Bianca", "Caio", "Diego", "Estela", "Felipe", "Giovana", "Henrique", "Isabela", "Jonas",
    "Karen", "Leonardo", "Marta", "Nicole", "Olivia", "Pedro", "Quintino", "Rafaela", "Samuel", "Tatiane",
    "Ulisses", "Valeria", "William", "Xavier", "Yuri", "Zilda",
    "Adriana", "Breno", "Catarina", "Davi", "Eliane", "Fabio", "Gustavo", "Heloisa", "Inacio", "Juliana",
    "Kaique", "Lorena", "Mateus", "Nadia", "Orlando", "Priscila", "Raquel", "Sérgio", "Talita", "Ubirajara",
    "Vanessa", "Wesley", "Xuxa", "Yago", "Zuleica",
    "Amelia", "Bernardo", "Claudia", "Douglas", "Emanuel", "Francisco", "Graziella", "Heitor", "Isaque", "Julia",
    "Kauan", "Livia", "Mauricio", "Natanael", "Osvaldo", "Patricia", "Renato", "Simone", "Tobias", "Ursula",
    "Vinicius", "Wellington", "Xande", "Yohanna", "Zion",
    "Alexandre", "Beatriz", "Cristiano", "Debora", "Elisa", "Fabiana", "Geovana", "Hugo", "Ivana", "Jose",
    "Kelly", "Leandro", "Marcela", "Noemi", "Otilia", "Paulo", "Rodrigo", "Silvia"
]


dfcontas['numero_conta'] = indices_formatados

dfcontas['cliente'] = lista


dfcontas
# Out:
# C:\Users\lcone\AppData\Local\Temp\ipykernel_1336\2850326915.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfcontas['numero_conta'] = indices_formatados
# C:\Users\lcone\AppData\Local\Temp\ipykernel_1336\2850326915.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfcontas['cliente'] = lista
#         Data    saldo numero_conta  cliente
# 0     Jan. 1  1914.56         0001      Ana
# 1     Jan. 2  1919.55         0002    Bruno
# 2     Jan. 3  2171.62         0003   Carlos
# ...

# %%
dfcontas[['numero_conta','cliente', 'saldo']].to_csv("contas20.csv",index=False)
